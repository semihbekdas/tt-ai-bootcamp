# %%
name = ["Joe","Jack","William","Avarel"]

surname = ["Dalton"] * len(name)

# %%
daltons = [(n,s) for n,s in zip(name,surname)]
daltons
# Out:
# [('Joe', 'Dalton'),
#  ('Jack', 'Dalton'),
#  ('William', 'Dalton'),
#  ('Avarel', 'Dalton')]

# %%
even,odd = [], [] 
for i in range(101):
    if i % 2 == 0:
        even.append(i)
    else:
        odd.append(i)

# %%
even = [i for i in range(101) if i%2 == 0]
odd = [i for i in range(101) if i%2 == 1]
