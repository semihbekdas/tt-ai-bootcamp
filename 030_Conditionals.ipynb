# %%
temp = 23

# %%
if temp < 25:
    print("A good day for a walk")
elif temp < 30:
    print("Good day for swim")
else:
    print("Find a climate control")
# Out:
# A good day for a walk

# %%
"Good dat for a walk" if temp < 25 else "Good day for a swim"
# Out:
# 'Good dat for a walk'
