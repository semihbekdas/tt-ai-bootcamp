# %%
lst = [0,1,2,3,4,5]

lst_hetero = [None, True, False,  "Erwin", 3.14, 9 ]

lst_auto = list(range(6))

# %%
for element in lst:
    print(element)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i,element in enumerate(lst_hetero):
    print(i, element)
# Out:
# 0 None
# 1 True
# 2 False
# 3 Erwin
# 4 3.14
# 5 9

# %%
for i, (e1,e2) in enumerate(zip(lst,lst_hetero,strict=True)):
    print(i, e1, e2)
# Out:
# 0 0 None
# 1 1 True
# 2 2 False
# 3 3 Erwin
# 4 4 3.14
# 5 5 9
