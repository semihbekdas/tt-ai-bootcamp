# %%
3
# Out:
# 3

# %%
1+1
# Out:
# 2

# %%
7-3
# Out:
# 4

# %%
5/4
# Out:
# 1.25

# %%
5//4
# Out:
# 1

# %%
5%3
# Out:
# 2

# %%
"Hello World. This is 'Husnu Sensoy'"
# Out:
# "Hello World. This is 'Husnu Sensoy'"

# %%
'Hello World. This is "Husnu Sensoy"'
# Out:
# 'Hello World. This is "Husnu Sensoy"'
