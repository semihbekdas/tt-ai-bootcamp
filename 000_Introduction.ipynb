# %% [markdown]
# ## Content
#
# ### Week 1
# - Introduction to AI
# - Introduction to Python
# - Introduction to SQL (Duckdb)
# - ML Fundamental
# - Deep Learning
# - GenAI LLM
#
# ### Week 2
# - Advanced Machine Learning
# - Embeddings and RAGs
# - MCP, Agents, AgentOps
#
# ## General Rules
# * Interrupt, ask and talk !!!
# * Try to keep your screens at all times for online sessions
# * A short break in every 45 min
# * I/We/You Dos
# * Capstone

# %% [markdown]
# ## AI
#
# - Rule based
# - Search algortithms
#   - DFS, BFS
#   - CSP
#   - Beam Search
#   - Dynamic Programming
# - Logic
# - Probabilistic Reasoning
# - Machine Learning
#   - Supervised/Unsupervised
#   - Reinforcement Learning
#   - Deep Learning
#   - Transformer Models and forward
# - Communication, Perceiving and Acting
#   - NLP
#   - Computer vision
#   - Robotics and Control Theory
#
# [Artificial Intelligence: A Modern Approach, 4th US ed.
# , Peter Norvig](https://aima.cs.berkeley.edu/)
