# %%
bool_v1 = True
bool_v2 = False
bool_v3 = None

# %%
bool_v1 == bool_v2
# Out:
# False

# %%
bool_v1 == (not bool_v2)
# Out:
# True

# %%
bool_v1 == bool_v3
# Out:
# False

# %%
bool_v2 == bool_v3
# Out:
# False

# %%
bool_v3 is None
# Out:
# True

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
1 < 2 < 3
# Out:
# True

# %%
one = 1
bir = 1
yek = 1

# %%
one == bir == yek
# Out:
# True
