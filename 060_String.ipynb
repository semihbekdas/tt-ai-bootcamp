# %%
s = "Hello World"
s
# Out:
# 'Hello World'

# %%
name = "husnu"
surname = "sensoy"

# %%
welcome = f"Hello {name} {surname}"
welcome
# Out:
# 'Hello husnu sensoy'

# %%
welcome = f"Hello {name.title()} {surname.title()}"
welcome
# Out:
# 'Hello Husnu Sensoy'

# %%
text = "The quick brown fox jumps over the lazy dog"

# %%
text.split()
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']

# %%
stop_words = ["the", "a","of"]
[token.lower()[:3] for token in text.split() if token.lower() not in stop_words]
# Out:
# ['qui', 'bro', 'fox', 'jum', 'ove', 'laz', 'dog']

# %%
text[0]
# Out:
# 'T'

# %%
text[:3]
# Out:
# 'The'

# %%
text[-3:]
# Out:
# 'dog'

# %%
text[1:3]
# Out:
# 'he'

# %%
text[-5]
# Out:
# 'y'
